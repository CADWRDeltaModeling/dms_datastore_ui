# %%
import pandas as pd
import hvplot.pandas
import geoviews as gv
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df = pd.read_csv('c:/Users/psandhu/Downloads/station/station.csv')
#df.hvplot.points('Longitude', 'Latitude', geo=True, tiles='OSM') * gv.tile_sources.OSM

# %%
df
# Out:
#          OrganizationIdentifier  \
# 0                       USGS-CA
# 1                       USGS-CA
# 2                       USGS-CA
# 3                       USGS-CA
# 4                       USGS-CA
# ..                          ...
# 886                     SIR_WQX
# 887  TABLEMOUNTAINRANCHERIA_WQX
# 888  TABLEMOUNTAINRANCHERIA_WQX
# 889  TABLEMOUNTAINRANCHERIA_WQX
# 890  TABLEMOUNTAINRANCHERIA_WQX
#
#                                OrganizationFormalName  \
# 0                USGS California Water Science Center
# 1                USGS California Water Science Center
# 2                USGS California Water Science Center
# 3                USGS California Water Science Center
# 4                USGS California Water Science Center
# ..                                                ...
# 886  Susanville Indian Rancheria, California (Tribal)
# 887   Table Mountain Rancheria of California (Tribal)
# 888   Table Mountain Rancheria of California (Tribal)
# ...

# %%
df=df.astype({'LatitudeMeasure': 'float64', 'LongitudeMeasure': 'float64'})

# %%
df.hvplot.points('LongitudeMeasure', 'LatitudeMeasure', geo=True, tiles='OSM', hover_cols=['MonitoringLocationName', 'MonitoringLocationIdentifier'])
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [LongitudeMeasure,LatitudeMeasure]   (MonitoringLocationName,MonitoringLocationIdentifier)
